# %%
import numpy as np
import bqplot.pyplot as plt
from bqplot import CATEGORY10, ColorScale , DateScale, LinearScale, Lines, Axis, Figure , OrdinalScale , Bars , Axis
from lib.ENTSOE import fetch_production, VALIDATIONS
import pandas as pd
from datetime import datetime, timedelta
import lib
from pkgutil import iter_modules
import importlib

#print(VALIDATIONS)
p =  VALIDATIONS.keys()
t = list(p)
find = str(input("veuillez rentrer le code du pays correspondant : "))
fetch = fetch_production(find)

cAT = fetch_production('AT')
cBE = fetch_production('BE')
cBG = fetch_production('BG')
cCH = fetch_production('CH')
cCZ = fetch_production('CZ')
cDE = fetch_production('DE')
cEE = fetch_production('EE')
cES = fetch_production('ES')
cFI = fetch_production('FI')
cGB = fetch_production('GB')
cGR = fetch_production('GR')
cHU = fetch_production('HU')
cIE = fetch_production('IE')
cIT = fetch_production('IT')
cPL = fetch_production('PL')
cPT = fetch_production('PT')
cRO = fetch_production('RO')
cRS = fetch_production('RS')
cSI = fetch_production('SI')
cSK = fetch_production('SK')

a = ['cAT', 'cBE', 'cBG', 'cCH', 'cCZ', 'cDE', 'cEE', 'cES', 'cFI', 'cGB', 'cGR', 'cHU', 'cIE', 'cIT', 'cPL', 'cPT', 'cRO', 'cRS', 'cSI', 'cSK']

if fetch == a[6] or fetch == a[12] or fetch == a[13] or fetch == a[14] or fetch == a[17]:
    param_production = [param1['production'] for param1 in fetch ]
    param_coal = [param1['coal'] for param1 in param_production]
    param2 = [param['datetime'] for param in fetch]
#production_data = [param_coal,param_gas,param_oil,param_solar,param_biomass,param_hydro,param_wind]
    production_data = [param_coal]
    time_data = np.array(param2,dtype='datetime64')
    fig = plt.figure(title="Electricity production")
    axes_options = {"x": {"label": "time "}, "y": {"label": "production (MWh) ","label_offset" : "6ex"}}
    bar1 =  plt.bar(time_data,production_data,colors=CATEGORY10, labels= ["Coal"],display_legend=True,)
#bar1 =  plt.bar(time_data,production_data,colors=CATEGORY10, labels=["oil", "Biomass", "Coal","Wind","Hydro","Gas","","Nuclear"],display_legend=True,)
    axes = plt.axes(options = axes_options)
    fig

elif fetch == a[18] or fetch == a[19] :
    param_production = [param1['production'] for param1 in fetch ]
    param_nuclear = [param1['nuclear'] for param1 in param_production]
    param2 = [param['datetime'] for param in fetch]
    production_data = [param_nuclear]
    time_data = np.array(param2,dtype='datetime64')
    fig = plt.figure(title="Electricity production")
    axes_options = {"x": {"label": "time "}, "y": {"label": "production (MWh) ","label_offset" : "6ex"}}
    bar1 =  plt.bar(time_data,production_data,colors=CATEGORY10, labels= ["Coal"],display_legend=True,)
    axes = plt.axes(options = axes_options)
    fig

elif fetch == a[7] or fetch == a[11] :
    param_production = [param1['production'] for param1 in fetch ]
    param_nuclear = [param1['nuclear'] for param1 in param_production]
    param_coal = [param1['coal'] for param1 in param_production]
    param2 = [param['datetime'] for param in fetch]
    production_data = [param_nuclear,param_coal]
    time_data = np.array(param2,dtype='datetime64')
    fig = plt.figure(title="Electricity production")
    axes_options = {"x": {"label": "time "}, "y": {"label": "production (MWh) ","label_offset" : "6ex"}}
    bar1 =  plt.bar(time_data,production_data,colors=CATEGORY10, labels= ["Coal","Nuclear"],display_legend=True,)
    axes = plt.axes(options = axes_options)
    fig 
    
elif fetch == a[15] or fetch == a[10] :
    param_production = [param1['production'] for param1 in fetch ]
    param_gas = [param1['gas'] for param1 in param_production]
    param_coal = [param1['coal'] for param1 in param_production]
    param2 = [param['datetime'] for param in fetch]
    production_data = [param_gas,param_coal]
    time_data = np.array(param2,dtype='datetime64')
    fig = plt.figure(title="Electricity production")
    axes_options = {"x": {"label": "time "}, "y": {"label": "production (MWh) ","label_offset" : "6ex"}}
    bar1 =  plt.bar(time_data,production_data,colors=CATEGORY10, labels= ["Coal","Gas"],display_legend=True,)
    axes = plt.axes(options = axes_options)
    fig 
        
elif fetch == a[9] :
    param_production = [param1['production'] for param1 in fetch ]
    param_gas = [param1['gas'] for param1 in param_production]
    param_coal = [param1['coal'] for param1 in param_production]
    param_nuclear = [param1['nuclear'] for param1 in param_production]
    param2 = [param['datetime'] for param in fetch]
    production_data = [param_gas,param_coal,param_nuclear]
    time_data = np.array(param2,dtype='datetime64')
    fig = plt.figure(title="Electricity production")
    axes_options = {"x": {"label": "time "}, "y": {"label": "production (MWh) ","label_offset" : "6ex"}}
    bar1 =  plt.bar(time_data,production_data,colors=CATEGORY10, labels= ["Coal","Gas"],display_legend=True,)
    axes = plt.axes(options = axes_options)
    fig 

elif fetch == a[5]:
    param_production = [param1['production'] for param1 in a]
    param_coal = [param1['coal'] for param1 in param_production]
    param_gas = [param1['gas'] for param1 in param_production]
    param_oil = [param1['oil'] for param1 in param_production]
    param_solar = [param1['solar'] for param1 in param_production]
    param_nuclear = [param1['nuclear'] for param1 in param_production]
    param_biomass = [param1['biomass'] for param1 in param_production]
    param_hydro = [param1['hydro'] for param1 in param_production]
    param_wind =[param1['wind'] for param1 in param_production]
    param_unknow = [param1['unknown'] for param1 in param_production]
    param2 = [param['datetime'] for param in a]
    production_data = [param_coal,param_gas,param_oil,param_solar,param_biomass,param_hydro,param_wind,param_unknow]
    time_data = np.array(param2,dtype='datetime64')
    fig = plt.figure(title="Electricity production")
    axes_options = {"x": {"label": "time "}, "y": {"label": "production (MWh) ","label_offset" : "6ex"}}
    bar1 =  plt.bar(time_data,production_data,colors=CATEGORY10, labels=["oil", "Biomass", "Coal","Wind","Hydro","Gas","","Nuclear","Unknown"],display_legend=True,)
    axes = plt.axes(options = axes_options)
    fig
    
elif fetch == a[0]:
    param_production = [param1['production'] for param1 in fetch ]
    param_hydro = [param1['hydro'] for param1 in param_production]
    param2 = [param['datetime'] for param in fetch]
    production_data = [param_hydro]
    time_data = np.array(param2,dtype='datetime64')
    fig = plt.figure(title="Electricity production")
    axes_options = {"x": {"label": "time "}, "y": {"label": "production (MWh) ","label_offset" : "6ex"}}
    bar1 =  plt.bar(time_data,production_data,colors=CATEGORY10, labels= ["Hydro"],display_legend=True,)
    axes = plt.axes(options = axes_options)
    fig

elif fetch == a[1]:
    param_production = [param1['production'] for param1 in fetch ]
    param_gas = [param1['gas'] for param1 in param_production]
    param_nuclear = [param1['nuclear'] for param1 in param_production]
    param2 = [param['datetime'] for param in fetch]
    production_data = [param_gas,param_nuclear]
    time_data = np.array(param2,dtype='datetime64')
    fig = plt.figure(title="Electricity production")
    axes_options = {"x": {"label": "time "}, "y": {"label": "production (MWh) ","label_offset" : "6ex"}}
    bar1 =  plt.bar(time_data,production_data,colors=CATEGORY10, labels= ["Gas","Nuclear"],display_legend=True,)
    axes = plt.axes(options = axes_options)
    fig

elif fetch == a[2] or fetch == a[16]:
    param_production = [param1['production'] for param1 in fetch ]
    param_coal = [param1['coal'] for param1 in param_production]
    param_nuclear = [param1['nuclear'] for param1 in param_production]
    param_hydro = [param1['hydro'] for param1 in param_production]
    param2 = [param['datetime'] for param in fetch]
    production_data = [param_coal,param_nuclear,param_hydro]
    time_data = np.array(param2,dtype='datetime64')
    fig = plt.figure(title="Electricity production")
    axes_options = {"x": {"label": "time "}, "y": {"label": "production (MWh) ","label_offset" : "6ex"}}
    bar1 =  plt.bar(time_data,production_data,colors=CATEGORY10, labels= ["Coal","Nuclear","Hydro"],display_legend=True,)
    axes = plt.axes(options = axes_options)
    fig

elif fetch == a[3] :
    param_production = [param1['production'] for param1 in fetch ]
    param_nuclear = [param1['nuclear'] for param1 in param_production]
    param_hydro = [param1['hydro'] for param1 in param_production]
    param2 = [param['datetime'] for param in fetch]
    production_data = [param_nuclear,param_hydro]
    time_data = np.array(param2,dtype='datetime64')
    fig = plt.figure(title="Electricity production")
    axes_options = {"x": {"label": "time "}, "y": {"label": "production (MWh) ","label_offset" : "6ex"}}
    bar1 =  plt.bar(time_data,production_data,colors=CATEGORY10, labels= ["Nuclear","Hydro"],display_legend=True,)
    axes = plt.axes(options = axes_options)
    fig

elif fetch == a[8]:
    param_production = [param1['production'] for param1 in fetch]
    param_coal = [param1['coal'] for param1 in param_production]
    param_nuclear = [param1['nuclear'] for param1 in param_production]
    param_biomass = [param1['biomass'] for param1 in param_production]
    param_hydro = [param1['hydro'] for param1 in param_production]
    param2 = [param['datetime'] for param in fetch]
    production_data = [param_coal,param_nuclear,param_biomass,param_hydro]
    time_data = np.array(param2,dtype='datetime64')
    fig = plt.figure(title="Electricity production")
    axes_options = {"x": {"label": "time "}, "y": {"label": "production (MWh) ","label_offset" : "6ex"}}
    bar1 =  plt.bar(time_data,production_data,colors=CATEGORY10, labels=["Biomass", "Coal","Hydro","Nuclear"],display_legend=True,)
    axes = plt.axes(options = axes_options)
    fig
