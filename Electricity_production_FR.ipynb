# %%
import numpy as np
import bqplot.pyplot as plt
from bqplot import CATEGORY10, ColorScale , DateScale, LinearScale, Lines, Axis, Figure , OrdinalScale , Bars , Axis
from lib.FR import fetch_production
import pandas as pd
from datetime import datetime, timedelta

a = fetch_production('FR')
b = fetch_production('AW')
param_production_FR = [param1['production'] for param1 in a]
param_coal = [param1['coal'] for param1 in param_production]
param_gas = [param1['gas'] for param1 in param_production]
param_oil = [param1['oil'] for param1 in param_production]
param_solar = [param1['solar'] for param1 in param_production]
param_biomass = [param1['biomass'] for param1 in param_production]
param_hydro = [param1['hydro'] for param1 in param_production]
param_wind =[param1['wind'] for param1 in param_production]
param2 = [param['datetime'] for param in a]


production_data = [param_coal,param_gas,param_oil,param_solar,param_biomass,param_hydro,param_wind]
time_data = np.array(param2,dtype='datetime64')


fig = plt.figure(title="Electricity production")

axes_options = {"x": {"label": "time "}, "y": {"label": "production (MWh) ","label_offset" : "6ex"}}
bar1 =  plt.bar(time_data,production_data,colors=CATEGORY10)
axes = plt.axes(options = axes_options)

fig
# Out:
# /var/folders/d3/jm92yqd96dz8jxjznnxtzjmm0000gp/T/ipykernel_7634/2626916155.py:22: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   time_data = np.array(param2,dtype='datetime64')
# Figure(axes=[Axis(label='time ', scale=DateScale()), Axis(label='production (MWh) ', label_offset='6ex', orien…

# %%
a
# Out:
# [{'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 11, 30, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48531.0,
#    'coal': 73.0,
#    'gas': 7932.0,
#    'oil': 212.0,
#    'wind': 2954.0,
#    'solar': 3751.0,
#    'biomass': 890.0,
#    'hydro': 5588.0},
#   'storage': {'hydro': 103.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 11, 45, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48542.0,
#    'coal': 73.0,
#    'gas': 7955.0,
#    'oil': 212.0,
#    'wind': 3032.0,
#    'solar': 3916.0,
#    'biomass': 893.0,
#    'hydro': 5541.0},
#   'storage': {'hydro': 116.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 12, 0, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48512.0,
#    'coal': 72.0,
#    'gas': 7920.0,
#    'oil': 211.0,
#    'wind': 3112.0,
#    'solar': 4091.0,
#    'biomass': 887.0,
#    'hydro': 5646.0},
#   'storage': {'hydro': 135.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 12, 15, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48542.0,
#    'coal': 72.0,
#    'gas': 7959.0,
#    'oil': 213.0,
#    'wind': 3104.0,
#    'solar': 4164.0,
#    'biomass': 892.0,
#    'hydro': 5764.0},
#   'storage': {'hydro': 29.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 12, 30, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48513.0,
#    'coal': 72.0,
#    'gas': 7783.0,
#    'oil': 211.0,
#    'wind': 3145.0,
#    'solar': 4236.0,
#    'biomass': 885.0,
#    'hydro': 5668.0},
#   'storage': {'hydro': 65.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 12, 45, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48495.0,
#    'coal': 72.0,
#    'gas': 7935.0,
#    'oil': 211.0,
#    'wind': 3108.0,
#    'solar': 4283.0,
#    'biomass': 890.0,
#    'hydro': 5708.0},
#   'storage': {'hydro': 29.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 13, 0, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48510.0,
#    'coal': 73.0,
#    'gas': 7871.0,
#    'oil': 213.0,
#    'wind': 3039.0,
#    'solar': 4326.0,
#    'biomass': 892.0,
#    'hydro': 5643.0},
#   'storage': {'hydro': 54.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 13, 15, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48530.0,
#    'coal': 75.0,
#    'gas': 7941.0,
#    'oil': 213.0,
#    'wind': 2970.0,
#    'solar': 4327.0,
#    'biomass': 897.0,
#    'hydro': 5638.0},
#   'storage': {'hydro': 628.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 13, 30, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48478.0,
#    'coal': 75.0,
#    'gas': 7901.0,
#    'oil': 212.0,
#    'wind': 2992.0,
#    'solar': 4295.0,
#    'biomass': 894.0,
#    'hydro': 5427.0},
#   'storage': {'hydro': 664.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 13, 45, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48436.0,
#    'coal': 73.0,
#    'gas': 7915.0,
#    'oil': 213.0,
#    'wind': 2953.0,
#    'solar': 4178.0,
#    'biomass': 884.0,
#    'hydro': 5342.0},
#   'storage': {'hydro': 1744.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 14, 0, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48400.0,
#    'coal': 73.0,
#    'gas': 7904.0,
#    'oil': 212.0,
#    'wind': 2975.0,
#    'solar': 4112.0,
#    'biomass': 888.0,
#    'hydro': 5173.0},
#   'storage': {'hydro': 1752.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 14, 15, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48544.0,
#    'coal': 73.0,
#    'gas': 8245.0,
#    'oil': 213.0,
#    'wind': 2946.0,
#    'solar': 3941.0,
#    'biomass': 897.0,
#    'hydro': 4948.0},
#   'storage': {'hydro': 1834.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 14, 30, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48420.0,
#    'coal': 75.0,
#    'gas': 7978.0,
#    'oil': 213.0,
#    'wind': 2923.0,
#    'solar': 3773.0,
#    'biomass': 886.0,
#    'hydro': 4548.0},
#   'storage': {'hydro': 1970.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 14, 45, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48441.0,
#    'coal': 73.0,
#    'gas': 8172.0,
#    'oil': 213.0,
#    'wind': 2939.0,
#    'solar': 3541.0,
#    'biomass': 896.0,
#    'hydro': 4557.0},
#   'storage': {'hydro': 2333.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 15, 0, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48420.0,
#    'coal': 75.0,
#    'gas': 8014.0,
#    'oil': 213.0,
#    'wind': 2843.0,
#    'solar': 3310.0,
#    'biomass': 891.0,
#    'hydro': 4525.0},
#   'storage': {'hydro': 2372.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 15, 15, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48451.0,
#    'coal': 74.0,
#    'gas': 8184.0,
#    'oil': 213.0,
#    'wind': 2766.0,
#    'solar': 3013.0,
#    'biomass': 884.0,
#    'hydro': 4580.0},
#   'storage': {'hydro': 2629.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 15, 30, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48435.0,
#    'coal': 75.0,
#    'gas': 8223.0,
#    'oil': 213.0,
#    'wind': 2750.0,
#    'solar': 2667.0,
#    'biomass': 888.0,
#    'hydro': 4640.0},
#   'storage': {'hydro': 2630.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 15, 45, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48378.0,
#    'coal': 74.0,
#    'gas': 8273.0,
#    'oil': 213.0,
#    'wind': 2668.0,
#    'solar': 2299.0,
#    'biomass': 893.0,
#    'hydro': 4720.0},
#   'storage': {'hydro': 2596.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 16, 0, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48321.0,
#    'coal': 74.0,
#    'gas': 8264.0,
#    'oil': 213.0,
#    'wind': 2685.0,
#    'solar': 1858.0,
#    'biomass': 893.0,
#    'hydro': 4954.0},
#   'storage': {'hydro': 2610.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 16, 15, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48227.0,
#    'coal': 74.0,
#    'gas': 7911.0,
#    'oil': 212.0,
#    'wind': 2653.0,
#    'solar': 1501.0,
#    'biomass': 888.0,
#    'hydro': 5545.0},
#   'storage': {'hydro': 1799.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 16, 30, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48304.0,
#    'coal': 73.0,
#    'gas': 7965.0,
#    'oil': 213.0,
#    'wind': 2647.0,
#    'solar': 1141.0,
#    'biomass': 888.0,
#    'hydro': 5700.0},
#   'storage': {'hydro': 1780.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 16, 45, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48332.0,
#    'coal': 72.0,
#    'gas': 7947.0,
#    'oil': 213.0,
#    'wind': 2606.0,
#    'solar': 810.0,
#    'biomass': 890.0,
#    'hydro': 6065.0},
#   'storage': {'hydro': 1201.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 17, 0, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48276.0,
#    'coal': 68.0,
#    'gas': 7961.0,
#    'oil': 212.0,
#    'wind': 2572.0,
#    'solar': 510.0,
#    'biomass': 883.0,
#    'hydro': 6289.0},
#   'storage': {'hydro': 1193.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 17, 15, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48528.0,
#    'coal': 63.0,
#    'gas': 8008.0,
#    'oil': 213.0,
#    'wind': 2564.0,
#    'solar': 352.0,
#    'biomass': 892.0,
#    'hydro': 7023.0},
#   'storage': {'hydro': 85.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 17, 30, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48527.0,
#    'coal': 69.0,
#    'gas': 8171.0,
#    'oil': 213.0,
#    'wind': 2563.0,
#    'solar': 266.0,
#    'biomass': 887.0,
#    'hydro': 7630.0},
#   'storage': {'hydro': -195.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 17, 45, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48579.0,
#    'coal': 71.0,
#    'gas': 8354.0,
#    'oil': 213.0,
#    'wind': 2539.0,
#    'solar': 223.0,
#    'biomass': 890.0,
#    'hydro': 8470.0},
#   'storage': {'hydro': -856.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 18, 0, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48549.0,
#    'coal': 72.0,
#    'gas': 8400.0,
#    'oil': 213.0,
#    'wind': 2506.0,
#    'solar': 204.0,
#    'biomass': 890.0,
#    'hydro': 8707.0},
#   'storage': {'hydro': -958.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 18, 15, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48514.0,
#    'coal': 73.0,
#    'gas': 8340.0,
#    'oil': 213.0,
#    'wind': 2519.0,
#    'solar': 205.0,
#    'biomass': 897.0,
#    'hydro': 8912.0},
#   'storage': {'hydro': -1309.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 18, 30, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48472.0,
#    'coal': 71.0,
#    'gas': 8409.0,
#    'oil': 212.0,
#    'wind': 2542.0,
#    'solar': 0.0,
#    'biomass': 889.0,
#    'hydro': 9235.0},
#   'storage': {'hydro': -1662.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 18, 45, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48549.0,
#    'coal': 70.0,
#    'gas': 8379.0,
#    'oil': 213.0,
#    'wind': 2546.0,
#    'solar': 0.0,
#    'biomass': 887.0,
#    'hydro': 9863.0},
#   'storage': {'hydro': -1931.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 19, 0, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48533.0,
#    'coal': 66.0,
#    'gas': 8451.0,
#    'oil': 213.0,
#    'wind': 2556.0,
#    'solar': 0.0,
#    'biomass': 885.0,
#    'hydro': 10060.0},
#   'storage': {'hydro': -1955.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 19, 15, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48565.0,
#    'coal': 65.0,
#    'gas': 8496.0,
#    'oil': 212.0,
#    'wind': 2583.0,
#    'solar': 0.0,
#    'biomass': 880.0,
#    'hydro': 10227.0},
#   'storage': {'hydro': -2051.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 19, 30, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48565.0,
#    'coal': 66.0,
#    'gas': 8474.0,
#    'oil': 213.0,
#    'wind': 2534.0,
#    'solar': 0.0,
#    'biomass': 871.0,
#    'hydro': 10130.0},
#   'storage': {'hydro': -1827.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 19, 45, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48625.0,
#    'coal': 67.0,
#    'gas': 8479.0,
#    'oil': 213.0,
#    'wind': 2473.0,
#    'solar': 0.0,
#    'biomass': 876.0,
#    'hydro': 9945.0},
#   'storage': {'hydro': -1800.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 20, 0, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48596.0,
#    'coal': 67.0,
#    'gas': 8479.0,
#    'oil': 213.0,
#    'wind': 2411.0,
#    'solar': 0.0,
#    'biomass': 880.0,
#    'hydro': 9813.0},
#   'storage': {'hydro': -1799.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 20, 15, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48618.0,
#    'coal': 64.0,
#    'gas': 8528.0,
#    'oil': 212.0,
#    'wind': 2328.0,
#    'solar': 0.0,
#    'biomass': 881.0,
#    'hydro': 9691.0},
#   'storage': {'hydro': -1898.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 20, 30, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48592.0,
#    'coal': 67.0,
#    'gas': 8459.0,
#    'oil': 212.0,
#    'wind': 2306.0,
#    'solar': 0.0,
#    'biomass': 886.0,
#    'hydro': 9471.0},
#   'storage': {'hydro': -1736.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 20, 45, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48592.0,
#    'coal': 63.0,
#    'gas': 8438.0,
#    'oil': 213.0,
#    'wind': 2199.0,
#    'solar': 0.0,
#    'biomass': 884.0,
#    'hydro': 8791.0},
#   'storage': {'hydro': -1494.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 21, 0, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48577.0,
#    'coal': 66.0,
#    'gas': 8454.0,
#    'oil': 212.0,
#    'wind': 2179.0,
#    'solar': 0.0,
#    'biomass': 881.0,
#    'hydro': 8773.0},
#   'storage': {'hydro': -1572.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 21, 15, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48597.0,
#    'coal': 66.0,
#    'gas': 8375.0,
#    'oil': 211.0,
#    'wind': 2104.0,
#    'solar': 0.0,
#    'biomass': 884.0,
#    'hydro': 8078.0},
#   'storage': {'hydro': -1561.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 21, 30, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48604.0,
#    'coal': 66.0,
#    'gas': 8418.0,
#    'oil': 212.0,
#    'wind': 2032.0,
#    'solar': 0.0,
#    'biomass': 892.0,
#    'hydro': 7753.0},
#   'storage': {'hydro': -1100.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 21, 45, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48581.0,
#    'coal': 66.0,
#    'gas': 8296.0,
#    'oil': 211.0,
#    'wind': 2024.0,
#    'solar': 0.0,
#    'biomass': 885.0,
#    'hydro': 7264.0},
#   'storage': {'hydro': -1044.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 22, 0, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48547.0,
#    'coal': 65.0,
#    'gas': 8148.0,
#    'oil': 211.0,
#    'wind': 2021.0,
#    'solar': 0.0,
#    'biomass': 880.0,
#    'hydro': 6855.0},
#   'storage': {'hydro': -760.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 22, 15, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48584.0,
#    'coal': 67.0,
#    'gas': 8156.0,
#    'oil': 212.0,
#    'wind': 2021.0,
#    'solar': 0.0,
#    'biomass': 884.0,
#    'hydro': 6678.0},
#   'storage': {'hydro': -1052.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 22, 30, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48562.0,
#    'coal': 59.0,
#    'gas': 8088.0,
#    'oil': 213.0,
#    'wind': 2013.0,
#    'solar': 0.0,
#    'biomass': 893.0,
#    'hydro': 6520.0},
#   'storage': {'hydro': -881.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 22, 45, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48654.0,
#    'coal': 58.0,
#    'gas': 8178.0,
#    'oil': 212.0,
#    'wind': 1974.0,
#    'solar': 0.0,
#    'biomass': 894.0,
#    'hydro': 6646.0},
#   'storage': {'hydro': -1154.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 23, 0, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48666.0,
#    'coal': 57.0,
#    'gas': 8219.0,
#    'oil': 213.0,
#    'wind': 1961.0,
#    'solar': 0.0,
#    'biomass': 901.0,
#    'hydro': 6744.0},
#   'storage': {'hydro': -1138.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 23, 15, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48670.0,
#    'coal': 53.0,
#    'gas': 8193.0,
#    'oil': 212.0,
#    'wind': 1969.0,
#    'solar': 0.0,
#    'biomass': 890.0,
#    'hydro': 6118.0},
#   'storage': {'hydro': -708.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 23, 30, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48683.0,
#    'coal': 54.0,
#    'gas': 8179.0,
#    'oil': 211.0,
#    'wind': 1933.0,
#    'solar': 0.0,
#    'biomass': 889.0,
#    'hydro': 5876.0},
#   'storage': {'hydro': -701.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 16, 23, 45, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48668.0,
#    'coal': 57.0,
#    'gas': 8118.0,
#    'oil': 211.0,
#    'wind': 1934.0,
#    'solar': 0.0,
#    'biomass': 881.0,
#    'hydro': 5744.0},
#   'storage': {'hydro': -696.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 0, 0, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48675.0,
#    'coal': 54.0,
#    'gas': 7987.0,
#    'oil': 212.0,
#    'wind': 1848.0,
#    'solar': 0.0,
#    'biomass': 884.0,
#    'hydro': 5820.0},
#   'storage': {'hydro': -762.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 0, 15, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48682.0,
#    'coal': 54.0,
#    'gas': 8279.0,
#    'oil': 213.0,
#    'wind': 1856.0,
#    'solar': 0.0,
#    'biomass': 896.0,
#    'hydro': 6742.0},
#   'storage': {'hydro': -467.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 0, 30, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48610.0,
#    'coal': 56.0,
#    'gas': 8139.0,
#    'oil': 211.0,
#    'wind': 1812.0,
#    'solar': 0.0,
#    'biomass': 885.0,
#    'hydro': 6387.0},
#   'storage': {'hydro': -92.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 0, 45, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48631.0,
#    'coal': 52.0,
#    'gas': 7928.0,
#    'oil': 212.0,
#    'wind': 1759.0,
#    'solar': 0.0,
#    'biomass': 889.0,
#    'hydro': 6073.0},
#   'storage': {'hydro': 364.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 1, 0, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48649.0,
#    'coal': 52.0,
#    'gas': 7734.0,
#    'oil': 211.0,
#    'wind': 1676.0,
#    'solar': 0.0,
#    'biomass': 891.0,
#    'hydro': 5865.0},
#   'storage': {'hydro': 391.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 1, 15, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48641.0,
#    'coal': 53.0,
#    'gas': 8083.0,
#    'oil': 212.0,
#    'wind': 1681.0,
#    'solar': 0.0,
#    'biomass': 891.0,
#    'hydro': 6143.0},
#   'storage': {'hydro': 479.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 1, 30, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48650.0,
#    'coal': 52.0,
#    'gas': 8038.0,
#    'oil': 213.0,
#    'wind': 1690.0,
#    'solar': 0.0,
#    'biomass': 897.0,
#    'hydro': 6111.0},
#   'storage': {'hydro': 487.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 1, 45, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48674.0,
#    'coal': 52.0,
#    'gas': 8000.0,
#    'oil': 211.0,
#    'wind': 1681.0,
#    'solar': 0.0,
#    'biomass': 895.0,
#    'hydro': 6059.0},
#   'storage': {'hydro': 313.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 2, 0, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48652.0,
#    'coal': 53.0,
#    'gas': 7918.0,
#    'oil': 212.0,
#    'wind': 1649.0,
#    'solar': 0.0,
#    'biomass': 892.0,
#    'hydro': 5916.0},
#   'storage': {'hydro': 331.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 2, 15, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48669.0,
#    'coal': 49.0,
#    'gas': 8127.0,
#    'oil': 211.0,
#    'wind': 1614.0,
#    'solar': 0.0,
#    'biomass': 895.0,
#    'hydro': 5830.0},
#   'storage': {'hydro': 271.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 2, 30, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48662.0,
#    'coal': 50.0,
#    'gas': 7923.0,
#    'oil': 211.0,
#    'wind': 1690.0,
#    'solar': 0.0,
#    'biomass': 889.0,
#    'hydro': 5436.0},
#   'storage': {'hydro': 317.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 2, 45, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48666.0,
#    'coal': 51.0,
#    'gas': 7882.0,
#    'oil': 212.0,
#    'wind': 1674.0,
#    'solar': 0.0,
#    'biomass': 894.0,
#    'hydro': 5352.0},
#   'storage': {'hydro': 748.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 3, 0, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48655.0,
#    'coal': 48.0,
#    'gas': 7684.0,
#    'oil': 211.0,
#    'wind': 1628.0,
#    'solar': 0.0,
#    'biomass': 885.0,
#    'hydro': 5026.0},
#   'storage': {'hydro': 739.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 3, 15, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48590.0,
#    'coal': 46.0,
#    'gas': 7348.0,
#    'oil': 211.0,
#    'wind': 1652.0,
#    'solar': 0.0,
#    'biomass': 886.0,
#    'hydro': 4991.0},
#   'storage': {'hydro': 697.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 3, 30, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48566.0,
#    'coal': 50.0,
#    'gas': 7088.0,
#    'oil': 211.0,
#    'wind': 1654.0,
#    'solar': 0.0,
#    'biomass': 882.0,
#    'hydro': 4938.0},
#   'storage': {'hydro': 712.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 3, 45, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48593.0,
#    'coal': 49.0,
#    'gas': 6980.0,
#    'oil': 212.0,
#    'wind': 1633.0,
#    'solar': 0.0,
#    'biomass': 886.0,
#    'hydro': 4809.0},
#   'storage': {'hydro': 1111.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 4, 0, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48565.0,
#    'coal': 51.0,
#    'gas': 6927.0,
#    'oil': 213.0,
#    'wind': 1648.0,
#    'solar': 0.0,
#    'biomass': 887.0,
#    'hydro': 4686.0},
#   'storage': {'hydro': 1135.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 4, 15, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48619.0,
#    'coal': 111.0,
#    'gas': 7055.0,
#    'oil': 213.0,
#    'wind': 1659.0,
#    'solar': 0.0,
#    'biomass': 884.0,
#    'hydro': 4552.0},
#   'storage': {'hydro': 1177.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 4, 30, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48616.0,
#    'coal': 233.0,
#    'gas': 7021.0,
#    'oil': 213.0,
#    'wind': 1660.0,
#    'solar': 0.0,
#    'biomass': 894.0,
#    'hydro': 4574.0},
#   'storage': {'hydro': 1183.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 4, 45, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48631.0,
#    'coal': 301.0,
#    'gas': 7008.0,
#    'oil': 211.0,
#    'wind': 1682.0,
#    'solar': 0.0,
#    'biomass': 891.0,
#    'hydro': 4743.0},
#   'storage': {'hydro': 1187.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 5, 0, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48650.0,
#    'coal': 335.0,
#    'gas': 7127.0,
#    'oil': 211.0,
#    'wind': 1611.0,
#    'solar': 0.0,
#    'biomass': 888.0,
#    'hydro': 4748.0},
#   'storage': {'hydro': 1192.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 5, 15, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48595.0,
#    'coal': 406.0,
#    'gas': 7762.0,
#    'oil': 211.0,
#    'wind': 1574.0,
#    'solar': 0.0,
#    'biomass': 887.0,
#    'hydro': 4980.0},
#   'storage': {'hydro': 1205.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 5, 30, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48631.0,
#    'coal': 488.0,
#    'gas': 8078.0,
#    'oil': 211.0,
#    'wind': 1555.0,
#    'solar': 0.0,
#    'biomass': 887.0,
#    'hydro': 5236.0},
#   'storage': {'hydro': 1186.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 5, 45, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48649.0,
#    'coal': 608.0,
#    'gas': 8305.0,
#    'oil': 212.0,
#    'wind': 1549.0,
#    'solar': 0.0,
#    'biomass': 891.0,
#    'hydro': 5476.0},
#   'storage': {'hydro': 546.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 6, 0, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48648.0,
#    'coal': 731.0,
#    'gas': 8294.0,
#    'oil': 211.0,
#    'wind': 1566.0,
#    'solar': 0.0,
#    'biomass': 890.0,
#    'hydro': 5428.0},
#   'storage': {'hydro': 550.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 6, 15, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48581.0,
#    'coal': 787.0,
#    'gas': 8114.0,
#    'oil': 213.0,
#    'wind': 1599.0,
#    'solar': 0.0,
#    'biomass': 888.0,
#    'hydro': 5882.0},
#   'storage': {'hydro': 318.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 6, 30, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48645.0,
#    'coal': 798.0,
#    'gas': 8040.0,
#    'oil': 211.0,
#    'wind': 1629.0,
#    'solar': 0.0,
#    'biomass': 896.0,
#    'hydro': 6341.0},
#   'storage': {'hydro': 264.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 6, 45, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48646.0,
#    'coal': 827.0,
#    'gas': 7952.0,
#    'oil': 210.0,
#    'wind': 1664.0,
#    'solar': 0.0,
#    'biomass': 894.0,
#    'hydro': 7829.0},
#   'storage': {'hydro': -193.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 7, 0, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48600.0,
#    'coal': 810.0,
#    'gas': 7959.0,
#    'oil': 211.0,
#    'wind': 1717.0,
#    'solar': 0.0,
#    'biomass': 879.0,
#    'hydro': 8207.0},
#   'storage': {'hydro': -192.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 7, 15, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48598.0,
#    'coal': 820.0,
#    'gas': 7986.0,
#    'oil': 213.0,
#    'wind': 1706.0,
#    'solar': 0.0,
#    'biomass': 889.0,
#    'hydro': 8763.0},
#   'storage': {'hydro': -165.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 7, 30, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48619.0,
#    'coal': 860.0,
#    'gas': 8042.0,
#    'oil': 213.0,
#    'wind': 1736.0,
#    'solar': 0.0,
#    'biomass': 890.0,
#    'hydro': 9646.0},
#   'storage': {'hydro': -561.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 7, 45, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48641.0,
#    'coal': 907.0,
#    'gas': 8082.0,
#    'oil': 213.0,
#    'wind': 1744.0,
#    'solar': 0.0,
#    'biomass': 890.0,
#    'hydro': 10077.0},
#   'storage': {'hydro': -878.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 8, 0, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48651.0,
#    'coal': 958.0,
#    'gas': 8028.0,
#    'oil': 210.0,
#    'wind': 1759.0,
#    'solar': 206.0,
#    'biomass': 876.0,
#    'hydro': 10549.0},
#   'storage': {'hydro': -1532.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 8, 15, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48587.0,
#    'coal': 939.0,
#    'gas': 7956.0,
#    'oil': 212.0,
#    'wind': 1754.0,
#    'solar': 235.0,
#    'biomass': 886.0,
#    'hydro': 10854.0},
#   'storage': {'hydro': -1626.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 8, 30, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48544.0,
#    'coal': 983.0,
#    'gas': 7946.0,
#    'oil': 209.0,
#    'wind': 1742.0,
#    'solar': 264.0,
#    'biomass': 876.0,
#    'hydro': 10873.0},
#   'storage': {'hydro': -1916.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 8, 45, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48583.0,
#    'coal': 1026.0,
#    'gas': 7962.0,
#    'oil': 212.0,
#    'wind': 1756.0,
#    'solar': 321.0,
#    'biomass': 877.0,
#    'hydro': 11140.0},
#   'storage': {'hydro': -1961.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 9, 0, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48626.0,
#    'coal': 1112.0,
#    'gas': 8028.0,
#    'oil': 212.0,
#    'wind': 1684.0,
#    'solar': 441.0,
#    'biomass': 891.0,
#    'hydro': 11354.0},
#   'storage': {'hydro': -2055.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 9, 15, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48692.0,
#    'coal': 1149.0,
#    'gas': 8170.0,
#    'oil': 211.0,
#    'wind': 1630.0,
#    'solar': 662.0,
#    'biomass': 877.0,
#    'hydro': 11557.0},
#   'storage': {'hydro': -3058.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 9, 30, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48727.0,
#    'coal': 1178.0,
#    'gas': 8152.0,
#    'oil': 210.0,
#    'wind': 1641.0,
#    'solar': 955.0,
#    'biomass': 875.0,
#    'hydro': 11375.0},
#   'storage': {'hydro': -2603.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 9, 45, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48705.0,
#    'coal': 1215.0,
#    'gas': 8177.0,
#    'oil': 210.0,
#    'wind': 1642.0,
#    'solar': 1259.0,
#    'biomass': 868.0,
#    'hydro': 11313.0},
#   'storage': {'hydro': -2601.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 10, 0, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48718.0,
#    'coal': 1215.0,
#    'gas': 8213.0,
#    'oil': 212.0,
#    'wind': 1640.0,
#    'solar': 1545.0,
#    'biomass': 877.0,
#    'hydro': 11292.0},
#   'storage': {'hydro': -2478.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 10, 15, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48695.0,
#    'coal': 1214.0,
#    'gas': 8230.0,
#    'oil': 212.0,
#    'wind': 1643.0,
#    'solar': 1912.0,
#    'biomass': 869.0,
#    'hydro': 10930.0},
#   'storage': {'hydro': -2308.0},
#   'source': 'opendata.reseaux-energies.fr'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 1, 17, 10, 30, tzinfo=tzoffset(None, 3600)),
#   'production': {'nuclear': 48708.0,
#    'coal': 1208.0,
#    'gas': 8236.0,
#    'oil': 210.0,
#    'wind': 1617.0,
#    'solar': 2256.0,
#    'biomass': 918.0,
#    'hydro': 10884.0},
#   'storage': {'hydro': -2151.0},
#   'source': 'opendata.reseaux-energies.fr'}]

# %%
plt.a
