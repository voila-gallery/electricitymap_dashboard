# %%
import numpy as np
import bqplot.pyplot as plt
from bqplot import CATEGORY10, ColorScale , DateScale, LinearScale, Lines, Axis, Figure , OrdinalScale , Bars
from lib.ENTSOE import fetch_price
import pandas as pd
import lib
from datetime import datetime, timedelta
from pkgutil import iter_modules
import importlib

find = str(input("veuillez rentrer le code du pays correspondant : "))
a = fetch_price(find)




param1 = [param['price'] for param in a]
param2 = [param['datetime'] for param in a]

display(a)
price_data = param1
datetime_data = np.array(param2,dtype='datetime64')

fig = plt.figure(title="Electricity price")
bar = plt.bar(datetime_data, price_data)
fig
# Out:
# veuillez rentrer le code du pays correspondant :  FR
# [{'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 12, 23, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 196.9,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 13, 0, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 186.52,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 13, 1, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 184.3,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 13, 2, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 162.15,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 13, 3, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 149.9,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 13, 4, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 169.4,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 13, 5, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 170.3,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 13, 6, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 191.08,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 13, 7, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 169.5,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 13, 8, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 169.8,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 13, 9, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 163.34,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 13, 10, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 148.3,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 13, 11, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 148.2,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 13, 12, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 117.92,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 13, 13, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 70.0,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 13, 14, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 93.07,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 13, 15, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 104.77,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 13, 16, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 123.9,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 13, 17, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 164.59,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 13, 18, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 181.92,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 13, 19, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 170.6,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 13, 20, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 122.8,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 13, 21, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 127.79,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 13, 22, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 119.27,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 13, 23, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 153.57,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 14, 0, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 150.0,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 14, 1, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 142.49,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 14, 2, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 107.5,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 14, 3, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 105.0,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 14, 4, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 146.96,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 14, 5, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 170.84,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 14, 6, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 217.51,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 14, 7, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 224.59,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 14, 8, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 228.2,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 14, 9, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 218.09,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 14, 10, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 200.42,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 14, 11, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 210.73,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 14, 12, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 195.05,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 14, 13, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 171.53,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 14, 14, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 156.11,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 14, 15, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 176.33,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 14, 16, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 202.33,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 14, 17, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 223.85,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 14, 18, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 248.71,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 14, 19, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 229.02,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 14, 20, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 218.95,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 14, 21, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 201.98,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 14, 22, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 194.81,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 14, 23, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 198.18,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 15, 0, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 189.0,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 15, 1, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 179.7,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 15, 2, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 173.4,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 15, 3, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 165.85,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 15, 4, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 169.3,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 15, 5, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 204.2,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 15, 6, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 234.06,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 15, 7, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 250.79,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 15, 8, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 240.0,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 15, 9, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 220.43,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 15, 10, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 202.38,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 15, 11, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 183.62,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 15, 12, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 162.9,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 15, 13, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 162.68,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 15, 14, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 162.52,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 15, 15, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 163.1,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 15, 16, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 188.87,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 15, 17, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 205.51,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 15, 18, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 230.69,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 15, 19, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 206.37,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 15, 20, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 200.57,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 15, 21, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 175.16,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 15, 22, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 173.4,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 15, 23, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 156.99,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 16, 0, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 155.38,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 16, 1, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 132.78,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 16, 2, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 117.56,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 16, 3, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 104.8,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 16, 4, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 111.58,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 16, 5, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 142.95,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 16, 6, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 188.39,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 16, 7, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 196.78,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 16, 8, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 186.37,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 16, 9, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 155.89,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 16, 10, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 157.41,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 16, 11, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 165.0,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 16, 12, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 155.2,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 16, 13, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 143.25,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 16, 14, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 138.17,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 16, 15, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 135.39,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 16, 16, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 152.58,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 16, 17, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 174.23,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 16, 18, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 195.45,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 16, 19, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 165.05,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 16, 20, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 150.48,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 16, 21, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 148.97,
#   'source': 'entsoe.eu'},
#  {'zoneKey': 'FR',
#   'datetime': datetime.datetime(2022, 2, 16, 22, 0, tzinfo=tzutc()),
#   'currency': 'EUR',
#   'price': 128.39,
#   'source': 'entsoe.eu'}]
# /var/folders/d3/jm92yqd96dz8jxjznnxtzjmm0000gp/T/ipykernel_51864/3758762357.py:22: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   datetime_data = np.array(param2,dtype='datetime64')
# Figure(axes=[Axis(scale=DateScale()), Axis(orientation='vertical', scale=LinearScale())], fig_margin={'top': 6…
